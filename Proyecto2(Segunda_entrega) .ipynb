# %%
# !pip install wbgapi
import wbgapi as wb

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy import stats

# %%
#Variables elegidas

# %%
wb.search('unemployment')  # desempleo

# %%
wb.series.metadata.get('SL.UEM.TOTL.ZS')

# %%
wb.search('gdp per capita') # PIB percapita en dolares

# %%
wb.series.metadata.get('NY.GDP.PCAP.CD')

# %%
wb.search('electricity') # Acceso a electricidad

# %%
wb.series.metadata.get('EG.ELC.ACCS.ZS')

# %%
wb.search('security') #Seguridad alimentaria

# %%
wb.series.metadata.get('AG.LND.AGRI.ZS')

# %%
wb.search('mortality') #Mortalidad neonatal por cada 1000

# %%
 wb.series.metadata.get('SH.DYN.NMRT')

# %%
### Tasa de desempleo  ###

# %%
d_unemployment = wb.data.DataFrame('SL.UEM.TOTL.ZS',
                                  economy=["COL","BRA","ARG","CHL","PER","ECU","URY","PRY","VEN","BOL","CAN","MEX","USA","CRI"],
                                  time=range(2002,2020),
                                  labels=True).reset_index(drop=True).set_index('Country').unstack().reset_index()
d_unemployment
# Out:
#     level_0        Country      0
# 0    YR2002     Costa Rica   6.33
# 1    YR2002  United States   5.78
# 2    YR2002         Mexico   3.00
# 3    YR2002         Canada   7.66
# 4    YR2002        Bolivia   2.49
# ..      ...            ...    ...
# 247  YR2019           Peru   3.38
# 248  YR2019          Chile   7.27
# 249  YR2019      Argentina   9.84
# 250  YR2019         Brazil  12.05
# 251  YR2019       Colombia   9.96
#
# [252 rows x 3 columns]

# %%
### PIB percapita en dolares ####

# %%
d_gdp = wb.data.DataFrame('NY.GDP.PCAP.CD',
                                  economy=["COL","BRA","ARG","CHL","PER","ECU","URY","PRY","VEN","BOL","CAN","MEX","USA","CRI"],
                                  time=range(2002,2020),
                                  labels=True).reset_index(drop=True).set_index('Country').unstack().reset_index()
d_gdp
# Out:
#     level_0        Country             0
# 0    YR2002     Costa Rica   4021.425361
# 1    YR2002  United States  37997.759657
# 2    YR2002         Mexico   7650.931864
# 3    YR2002         Canada  24255.338582
# 4    YR2002        Bolivia    888.198576
# ..      ...            ...           ...
# 247  YR2019           Peru   6955.881770
# 248  YR2019          Chile  14627.145016
# 249  YR2019      Argentina   9963.674231
# 250  YR2019         Brazil   8845.323931
# 251  YR2019       Colombia   6436.509215
#
# [252 rows x 3 columns]

# %%
### Acceso a electricidad ###

# %%
d_electricity = wb.data.DataFrame('EG.ELC.ACCS.ZS',
                                  economy=["COL","BRA","ARG","CHL","PER","ECU","URY","PRY","VEN","BOL","CAN","MEX","USA","CRI"],
                                  time=range(2002,2020),
                                  labels=True).reset_index(drop=True).set_index('Country').unstack().reset_index()
d_electricity
# Out:
#     level_0        Country           0
# 0    YR2002     Costa Rica   98.509188
# 1    YR2002  United States  100.000000
# 2    YR2002         Mexico   97.897085
# 3    YR2002         Canada  100.000000
# 4    YR2002        Bolivia   63.996855
# ..      ...            ...         ...
# 247  YR2019           Peru   95.551360
# 248  YR2019          Chile  100.000000
# 249  YR2019      Argentina  100.000000
# 250  YR2019         Brazil   99.800000
# 251  YR2019       Colombia   99.444260
#
# [252 rows x 3 columns]

# %%
 ###  seguridad alimentaria (AREA CULTIVABLE)###

# %%
d_securitya = wb.data.DataFrame('AG.LND.AGRI.ZS',
                                  economy=["COL","BRA","ARG","CHL","PER","ECU","URY","PRY","VEN","BOL","CAN","MEX","USA","CRI"],
                                  time=range(2002,2020),
                                  labels=True).reset_index(drop=True).set_index('Country').unstack().reset_index()
d_securitya
# Out:
#     level_0        Country          0
# 0    YR2002     Costa Rica  35.761849
# 1    YR2002  United States  45.084873
# 2    YR2002         Mexico  54.811081
# 3    YR2002         Canada   6.925478
# 4    YR2002        Bolivia  34.441983
# ..      ...            ...        ...
# 247  YR2019           Peru  19.123664
# 248  YR2019          Chile  15.239005
# 249  YR2019      Argentina  42.590779
# 250  YR2019         Brazil  28.490130
# 251  YR2019       Colombia  39.976566
#
# [252 rows x 3 columns]

# %%
### Tasa Mortalidad neonatal (PORCENTAJE NACIDOS QUE SE MUEREN ANTES DE LOS 28 DIAS###

# %%
d_morta = wb.data.DataFrame('SH.DYN.NMRT',
                                  economy=["COL","BRA","ARG","CHL","PER","ECU","URY","PRY","VEN","BOL","CAN","MEX","USA","CRI"],
                                  time=range(2002,2020),
                                  labels=True).reset_index(drop=True).set_index('Country').unstack().reset_index()
d_morta
# Out:
#     level_0        Country     0
# 0    YR2002     Costa Rica   7.3
# 1    YR2002  United States   4.6
# 2    YR2002         Mexico  12.3
# 3    YR2002         Canada   3.9
# 4    YR2002        Bolivia  27.9
# ..      ...            ...   ...
# 247  YR2019           Peru   7.5
# 248  YR2019          Chile   4.7
# 249  YR2019      Argentina   5.9
# 250  YR2019         Brazil   8.9
# 251  YR2019       Colombia   7.5
#
# [252 rows x 3 columns]

# %%
datafinal=(d_gdp.merge(d_morta,how='outer', on=['level_0','Country'])
      .merge(d_electricity,how='outer', on=['level_0','Country'])
      .merge(d_unemployment,how='outer', on=['level_0','Country'])
      .merge(d_securitya,how='outer', on=['level_0','Country']))
# Out:
# <ipython-input-36-50df6ace805b>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datafinal=(d_gdp.merge(d_morta,how='outer', on=['level_0','Country'])

# %%
datafinal
# Out:
#     level_0        Country           0_x   0_y         0_x    0_y          0
# 0    YR2002     Costa Rica   4021.425361   7.3   98.509188   6.33  35.761849
# 1    YR2002  United States  37997.759657   4.6  100.000000   5.78  45.084873
# 2    YR2002         Mexico   7650.931864  12.3   97.897085   3.00  54.811081
# 3    YR2002         Canada  24255.338582   3.9  100.000000   7.66   6.925478
# 4    YR2002        Bolivia    888.198576  27.9   63.996855   2.49  34.441983
# ..      ...            ...           ...   ...         ...    ...        ...
# 247  YR2019           Peru   6955.881770   7.5   95.551360   3.38  19.123664
# 248  YR2019          Chile  14627.145016   4.7  100.000000   7.27  15.239005
# 249  YR2019      Argentina   9963.674231   5.9  100.000000   9.84  42.590779
# 250  YR2019         Brazil   8845.323931   8.9   99.800000  12.05  28.490130
# 251  YR2019       Colombia   6436.509215   7.5   99.444260   9.96  39.976566
#
# [252 rows x 7 columns]

# %%
datafinal.columns=['año', 'pais', 'PIB per capita', 'Tasa Mortalidad', 'Acceso Electricidad', 'Tasa Desempleo', 'Seg Alimentaria']

# %%
datafinal.groupby('año').agg('mean')
# Out:
# <ipython-input-38-47a3e0957363>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datafinal.groupby('año').agg('mean')
#         PIB per capita  Tasa Mortalidad  Acceso Electricidad  Tasa Desempleo  \
# año
# YR2002     7174.998555        11.721429            93.084616        9.517071
# YR2003     7594.980317        11.350000            93.641503        9.047357
# YR2004     8492.291891        11.014286            94.304514        8.378071
# YR2005     9551.903872        10.657143            94.220898        7.423071
# YR2006    10634.294358        10.314286            95.368073        6.787714
# YR2007    11818.405170         9.957143            95.675511        6.175929
# YR2008    12962.255823         9.621429            96.442733        6.124286
# ...

# %%
datafinal.groupby('pais').agg('mean')
# Out:
# <ipython-input-39-210644ab5bd0>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datafinal.groupby('pais').agg('mean')
#                PIB per capita  Tasa Mortalidad  Acceso Electricidad  \
# pais
# Argentina         9455.806640         7.838889            98.387421
# Bolivia           2144.053480        21.277778            84.304573
# Brazil            8404.060096        11.716667            98.665525
# Canada           42991.217881         3.716667           100.000000
# Chile            11667.926901         5.222222            99.146694
# Colombia          5581.039255         9.955556            96.984663
# Costa Rica        8400.854538         6.600000            99.268121
# Ecuador           4706.581632         9.061111            97.203647
# ...

# %%
datafinal.groupby('año').agg('median')
# Out:
# <ipython-input-40-9be490231693>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datafinal.groupby('año').agg('median')
#         PIB per capita  Tasa Mortalidad  Acceso Electricidad  Tasa Desempleo  \
# año
# YR2002     3245.957795            11.50            96.959841          8.5250
# YR2003     3288.260854            10.85            96.639024          7.1900
# YR2004     4194.130188            10.40            97.149418          6.8500
# YR2005     4929.948121            10.15            97.387989          6.6650
# YR2006     5878.501157             9.90            98.049870          6.0300
# YR2007     7179.985091             9.70            97.976936          5.3750
# YR2008     8889.633163             9.45            98.385970          5.9600
# ...

# %%
datafinal.groupby('pais').agg('median')
# Out:
# <ipython-input-100-38546d34cc75>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#                PIB per capita  Tasa Mortalidad  Acceso Electricidad  \
# pais
# Argentina        10174.819331             7.55            98.927143
# Bolivia           2113.520479            21.45            88.144179
# Brazil            8792.486944            10.90            99.092815
# Canada           44894.662219             3.70           100.000000
# Chile            13168.865084             5.30            99.590927
# Colombia          6082.456322             9.85            96.803382
# Costa Rica        8642.349543             6.55            99.311614
# Ecuador           4921.451402             8.70            97.200752
# Mexico            9577.153022             8.95            99.058180
# ...

# %%
datafinal.groupby('año').agg('std')
# Out:
# <ipython-input-99-47570c192c72>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#         PIB per capita  Tasa Mortalidad  Acceso Electricidad  Tasa Desempleo  \
# año
# YR2002    10628.338697         6.306795            10.587688        5.535207
# YR2003    11457.804607         6.103309             8.851177        4.968412
# YR2004    12310.866281         5.900307             8.092040        4.141882
# YR2005    13243.848152         5.734338             9.392432        3.435225
# YR2006    14122.858844         5.557511             7.448894        2.976120
# YR2007    14872.593389         5.386124             6.314337        2.604646
# YR2008    14975.134939         5.171249             5.094107        2.355307
# YR2009    13833.244441         4.964600             4.486372        2.624339
# ...

# %%
datafinal.groupby('pais').agg('std')
# Out:
# <ipython-input-98-bb6bdf8bf5cb>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#                PIB per capita  Tasa Mortalidad  Acceso Electricidad  \
# pais
# Argentina         3908.135300         1.433687             1.471002
# Bolivia            955.630046         4.663192             9.243089
# Brazil            3267.643997         2.501117             1.169377
# Canada            8193.239834         0.172354             0.000000
# Chile             3838.935032         0.210198             0.955304
# Colombia          1949.140964         1.667059             1.328187
# Costa Rica        3183.228526         0.440588             0.332293
# Ecuador           1513.465270         1.950306             1.567425
# Mexico            1167.222984         1.099629             0.668001
# ...

# %%
for year in datafinal['año'].unique():
  print(year)
  print(datafinal[datafinal['año']==year].corr())
# Out:
# YR2002
#                      PIB per capita  Tasa Mortalidad  Acceso Electricidad  \
# PIB per capita             1.000000        -0.550304             0.349564
# Tasa Mortalidad           -0.550304         1.000000            -0.794568
# Acceso Electricidad        0.349564        -0.794568             1.000000
# Tasa Desempleo            -0.228776        -0.262718             0.427612
# Seg Alimentaria           -0.069636        -0.000938             0.159185
#
#                      Tasa Desempleo  Seg Alimentaria
# PIB per capita            -0.228776        -0.069636
# Tasa Mortalidad           -0.262718        -0.000938
# Acceso Electricidad        0.427612         0.159185
# Tasa Desempleo             1.000000         0.290531
# Seg Alimentaria            0.290531         1.000000
# YR2003
#                      PIB per capita  Tasa Mortalidad  Acceso Electricidad  \
# PIB per capita             1.000000        -0.548042             0.371142
# ...

# %%
###################        ANALISIS GRAFICO            ######################################

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# %%
##### TASA MORTALIDAD ####

# %%
fig = px.bar(datafinal, x='año', y='Tasa Mortalidad', color='pais',
             title='Tasa de Mortalidad por Año y País',
             labels={'Tasa de Mortalidad': 'Tasa de Mortalidad'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(datafinal, x='año', y='Tasa Mortalidad', color='pais',
              title='Tasa Mortalidad por Año y País',
              labels={'Tasa Mortalidad': 'Tasa Mortalidad'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(datafinal, x='año', y='Tasa Mortalidad', color='pais',
                 title='Gráfico de Dispersión de Tasa de Mortalidad por Año y País',
                 labels={'Tasa Mortalidad': 'Tasa de Mortalidad'}, symbol='pais')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
##### Tasa de Desempleo ###

# %%
fig = px.line(datafinal, x='año', y='Tasa Desempleo', color='pais',
              title='Tasa de Desempleo por Año y País',
              labels={'Tasa de Desempleo': 'Tasa de Desempleo'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(datafinal, x='año', y='Tasa Desempleo', color='pais',
                 title='Gráfico de Dispersión de Tasa Desempleo por Año y País',
                 labels={'Tasa Desempleo': 'Tasa Desempleo'}, symbol='pais')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
### PIB PER CAPITA ###

# %%
 fig = px.bar(datafinal, x='año', y='PIB per capita', color='pais',
             title='PIB per capita  por Año y País',
             labels={'PIB per capita ': 'PIB per capita '})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(datafinal, x='año', y='PIB per capita', color='pais',
                 title='Gráfico de Dispersión de PIB per capita por Año y País',
                 labels={'PIB per capita': 'PIB per capita'}, symbol='pais')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
##### Acceso Electricidad

# %%
fig = px.line(datafinal, x='año', y='Acceso Electricidad', color='pais',
              title='Acceso Electricidad por Año y País',
              labels={'Acceso Electricidad': 'Acceso Electricidad'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(datafinal, x='año', y='Acceso Electricidad', color='pais',
                 title='Gráfico de Dispersión de Acceso Electricidad por Año y País',
                 labels={'Acceso Electricidad': 'Acceso Electricidad'}, symbol='pais')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#### Seguridad Alimentaria

# %%
fig = px.line(datafinal, x='año', y='Seg Alimentaria', color='pais',
              title='Seguridad Alimentaria por Año y País',
              labels={'Seg Alimentaria': 'Seg Alimentaria'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(datafinal, x='año', y='Seg Alimentaria', color='pais',
                 title='Gráfico de Dispersión de Seguridad Alimentaria por Año y País',
                 labels={'Seg Alimentaria': 'Seg Alimentaria'}, symbol='pais')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
